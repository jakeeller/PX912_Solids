# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn

# %%
rel_err = []
for i in max_stress[0:-1]:
    rel_err.append(100*(abs(i-max_stress[-1]))/max_stress[-1])
print(rel_err)
# Out:
# [3736.055657891162, 1719.6957498325967, 663.5229872354229, 183.9769673006077]

# %%
no_nodes = [18, 72, 288,1152, 4608]
max_stress = [0.3337755347124298,0.158331884644293,0.066434201184097,0.0247088604962738, 0.00870100865262002]
max_d = [1.90333235148854,2.41045726950697, 2.702153535567033, 2.828431565340312,2.880163058015134]#*10**-10
max_strain = [266.24637539765,113.591891640921,42.8442709201822,15.2503381117763,5.30881339842132]#*10**-14
plt.scatter(no_nodes,max_stress, marker ='x')
plt.plot(no_nodes,max_stress)
plt.xlabel('Number of Elements')
plt.ylabel('Maximum Von Mises Stress ($N/m^2$)')
# Out:
# Text(0, 0.5, 'Maximum Von Mises Stress ($N/m^2$)')

# %%
plt.scatter(no_nodes,max_d, marker ='x')
plt.plot(no_nodes,max_d)
plt.xlabel('Number of Elements')
plt.ylabel('Maximum Nodal Displacement (x $10^-10$ m)')
# Out:
# Text(0, 0.5, 'Maximum Nodal Displacement (x $10^-10$ m)')

# %%
plt.scatter(no_nodes,max_strain, marker ='x')
plt.plot(no_nodes,max_strain)
plt.xlabel('Number of Elements')
plt.ylabel('Maximum Strain Element (x $10^-14$)')
# Out:
# Text(0, 0.5, 'Maximum Strain Element (x $10^-14$)')
